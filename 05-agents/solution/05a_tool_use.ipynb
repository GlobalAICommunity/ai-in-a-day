# %% [markdown]
# # 5a · Tool use — SOLUTION

# %%
import sys, os
sys.path.insert(0, os.path.abspath("../.."))
from shared.agent import run_agent
from shared.tools import read_only_tools

ARIA_SYSTEM = (
    "You are ARIA, the Orbital colony assistant. Use tools to get real data before "
    "answering. Be concise."
)

print(run_agent(ARIA_SYSTEM, "Is oxygen OK in Module B right now?", read_only_tools()))

# %%
print(run_agent(ARIA_SYSTEM, "Check CO2 in Module B and tell me the recovery procedure if it's high.", read_only_tools()))
